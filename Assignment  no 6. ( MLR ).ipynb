# %% [markdown]
# # Assignment 6: MlR

# %% [markdown]
# ## Importing LIbraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Importing Data

# %%
tc = pd.read_csv('ToyotaCorolla - MLR.csv')
tc
# Out:
#       Price  Age_08_04     KM Fuel_Type   HP  Automatic    cc  Doors  \
# 0     13500         23  46986    Diesel   90          0  2000      3
# 1     13750         23  72937    Diesel   90          0  2000      3
# 2     13950         24  41711    Diesel   90          0  2000      3
# 3     14950         26  48000    Diesel   90          0  2000      3
# 4     13750         30  38500    Diesel   90          0  2000      3
# ...     ...        ...    ...       ...  ...        ...   ...    ...
# 1431   7500         69  20544    Petrol   86          0  1300      3
# 1432  10845         72  19000    Petrol   86          0  1300      3
# 1433   8500         71  17016    Petrol   86          0  1300      3
# 1434   7250         70  16916    Petrol   86          0  1300      3
# 1435   6950         76      1    Petrol  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# 1             4      5    1165
# 2             4      5    1165
# 3             4      5    1165
# 4             4      5    1170
# ...         ...    ...     ...
# 1431          4      5    1025
# 1432          4      5    1015
# 1433          4      5    1015
# 1434          4      5    1015
# 1435          4      5    1114
#
# [1436 rows x 11 columns]

# %% [markdown]
# # EDA

# %%
tc.dtypes
# Out:
# Price         int64
# Age_08_04     int64
# KM            int64
# Fuel_Type    object
# HP            int64
# Automatic     int64
# cc            int64
# Doors         int64
# Cylinders     int64
# Gears         int64
# Weight        int64
# dtype: object

# %%
tc.isnull().sum()
# Out:
# Price        0
# Age_08_04    0
# KM           0
# Fuel_Type    0
# HP           0
# Automatic    0
# cc           0
# Doors        0
# Cylinders    0
# Gears        0
# Weight       0
# dtype: int64

# %%
tc.duplicated().sum()
# Out:
# 1

# %%
tc.drop_duplicates(inplace=True)

# %%
tc.duplicated().sum()
# Out:
# 0

# %%
# Dropping Cylinders because it has same value to all

tc.drop(columns=['Cylinders'],inplace = True)
tc.head()
# Out:
#    Price  Age_08_04     KM Fuel_Type  HP  Automatic    cc  Doors  Gears  \
# 0  13500         23  46986    Diesel  90          0  2000      3      5
# 1  13750         23  72937    Diesel  90          0  2000      3      5
# 2  13950         24  41711    Diesel  90          0  2000      3      5
# 3  14950         26  48000    Diesel  90          0  2000      3      5
# 4  13750         30  38500    Diesel  90          0  2000      3      5
#
#    Weight
# 0    1165
# 1    1165
# 2    1165
# 3    1165
# 4    1170

# %%
# As we can see that only text data is "Fuel_Type" so we put dummies into it

tcd = pd.get_dummies(tc,columns=['Fuel_Type'],dtype=int)
tcd
# Out:
#       Price  Age_08_04     KM   HP  Automatic    cc  Doors  Gears  Weight  \
# 0     13500         23  46986   90          0  2000      3      5    1165
# 1     13750         23  72937   90          0  2000      3      5    1165
# 2     13950         24  41711   90          0  2000      3      5    1165
# 3     14950         26  48000   90          0  2000      3      5    1165
# 4     13750         30  38500   90          0  2000      3      5    1170
# ...     ...        ...    ...  ...        ...   ...    ...    ...     ...
# 1431   7500         69  20544   86          0  1300      3      5    1025
# 1432  10845         72  19000   86          0  1300      3      5    1015
# 1433   8500         71  17016   86          0  1300      3      5    1015
# 1434   7250         70  16916   86          0  1300      3      5    1015
# 1435   6950         76      1  110          0  1600      5      5    1114
#
#       Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol
# 0                 0                 1                 0
# 1                 0                 1                 0
# 2                 0                 1                 0
# 3                 0                 1                 0
# 4                 0                 1                 0
# ...             ...               ...               ...
# 1431              0                 0                 1
# 1432              0                 0                 1
# 1433              0                 0                 1
# 1434              0                 0                 1
# 1435              0                 0                 1
#
# [1435 rows x 12 columns]

# %%
tcd.head()
# Out:
#    Price  Age_08_04     KM  HP  Automatic    cc  Doors  Gears  Weight  \
# 0  13500         23  46986  90          0  2000      3      5    1165
# 1  13750         23  72937  90          0  2000      3      5    1165
# 2  13950         24  41711  90          0  2000      3      5    1165
# 3  14950         26  48000  90          0  2000      3      5    1165
# 4  13750         30  38500  90          0  2000      3      5    1170
#
#    Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol
# 0              0                 1                 0
# 1              0                 1                 0
# 2              0                 1                 0
# 3              0                 1                 0
# 4              0                 1                 0

# %% [markdown]
# # Visualisation

# %%
# Histogram

plt.figure(figsize= (12,5))
plt.tight_layout()
tc.hist()
plt.subplots_adjust(hspace = 0.8 , wspace = 0.3)

# %%
# Pairplot

sns.pairplot(data = tc)

# %%
tcd.dtypes
# Out:
# Price               int64
# Age_08_04           int64
# KM                  int64
# HP                  int64
# Automatic           int64
# cc                  int64
# Doors               int64
# Gears               int64
# Weight              int64
# Fuel_Type_CNG       int32
# Fuel_Type_Diesel    int32
# Fuel_Type_Petrol    int32
# dtype: object

# %%
tcd.corr()
# Out:
#                      Price  Age_08_04        KM        HP  Automatic  \
# Price             1.000000  -0.876273 -0.569420  0.314134   0.033928
# Age_08_04        -0.876273   1.000000  0.504575 -0.155293   0.031354
# KM               -0.569420   0.504575  1.000000 -0.332904  -0.082168
# HP                0.314134  -0.155293 -0.332904  1.000000   0.013313
# Automatic         0.033928   0.031354 -0.082168  0.013313   1.000000
# cc                0.124375  -0.096549  0.103822  0.035207   0.066934
# Doors             0.183604  -0.146929 -0.035193  0.091803  -0.027492
# Gears             0.063831  -0.005629  0.014890  0.209642  -0.098582
# Weight            0.575869  -0.466484 -0.023969  0.087143   0.058499
# Fuel_Type_CNG    -0.039449   0.002198  0.144013  0.062203   0.001467
# Fuel_Type_Diesel  0.046612  -0.093058  0.407497 -0.537116  -0.084248
# Fuel_Type_Petrol -0.031356   0.088169 -0.437397  0.492362   0.079997
#
#                         cc     Doors     Gears    Weight  Fuel_Type_CNG  \
# Price             0.124375  0.183604  0.063831  0.575869      -0.039449
# Age_08_04        -0.096549 -0.146929 -0.005629 -0.466484       0.002198
# KM                0.103822 -0.035193  0.014890 -0.023969       0.144013
# HP                0.035207  0.091803  0.209642  0.087143       0.062203
# Automatic         0.066934 -0.027492 -0.098582  0.058499       0.001467
# cc                1.000000  0.079254  0.014732  0.335077       0.006019
# Doors             0.079254  1.000000 -0.160101  0.301734       0.009761
# Gears             0.014732 -0.160101  1.000000  0.021238      -0.049548
# Weight            0.335077  0.301734  0.021238  1.000000       0.053530
# Fuel_Type_CNG     0.006019  0.009761 -0.049548  0.053530       1.000000
# Fuel_Type_Diesel  0.326780  0.023538 -0.048706  0.564649      -0.037964
# Fuel_Type_Petrol -0.314200 -0.025746  0.063079 -0.557315      -0.297688
#
#                   Fuel_Type_Diesel  Fuel_Type_Petrol
# Price                     0.046612         -0.031356
# Age_08_04                -0.093058          0.088169
# KM                        0.407497         -0.437397
# HP                       -0.537116          0.492362
# Automatic                -0.084248          0.079997
# cc                        0.326780         -0.314200
# Doors                     0.023538         -0.025746
# Gears                    -0.048706          0.063079
# Weight                    0.564649         -0.557315
# Fuel_Type_CNG            -0.037964         -0.297688
# Fuel_Type_Diesel          1.000000         -0.942673
# Fuel_Type_Petrol         -0.942673          1.000000

# %%
# Heatmap

plt.figure(figsize=(12,6))
sns.heatmap(tcd.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Split the dataset into training and testing sets (e.g., 80% training, 20% testing).

# %%
x=tcd.drop(columns = ['Price'])
y=tcd['Price']
y
# Out:
# 0       13500
# 1       13750
# 2       13950
# 3       14950
# 4       13750
#         ...
# 1431     7500
# 1432    10845
# 1433     8500
# 1434     7250
# 1435     6950
# Name: Price, Length: 1435, dtype: int64

# %%
x
# Out:
#       Age_08_04     KM   HP  Automatic    cc  Doors  Gears  Weight  \
# 0            23  46986   90          0  2000      3      5    1165
# 1            23  72937   90          0  2000      3      5    1165
# 2            24  41711   90          0  2000      3      5    1165
# 3            26  48000   90          0  2000      3      5    1165
# 4            30  38500   90          0  2000      3      5    1170
# ...         ...    ...  ...        ...   ...    ...    ...     ...
# 1431         69  20544   86          0  1300      3      5    1025
# 1432         72  19000   86          0  1300      3      5    1015
# 1433         71  17016   86          0  1300      3      5    1015
# 1434         70  16916   86          0  1300      3      5    1015
# 1435         76      1  110          0  1600      5      5    1114
#
#       Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol
# 0                 0                 1                 0
# 1                 0                 1                 0
# 2                 0                 1                 0
# 3                 0                 1                 0
# 4                 0                 1                 0
# ...             ...               ...               ...
# 1431              0                 0                 1
# 1432              0                 0                 1
# 1433              0                 0                 1
# 1434              0                 0                 1
# 1435              0                 0                 1
#
# [1435 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split

xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2,random_state=1)

# %%
xtrain.head()
# Out:
#       Age_08_04      KM   HP  Automatic    cc  Doors  Gears  Weight  \
# 989          59   43818  110          0  1600      5      5    1070
# 907          65   58829  110          0  1600      3      5    1050
# 1318         78   67255  110          0  1600      5      5    1085
# 818          62   70500  110          0  1600      5      5    1035
# 661          65  111769  110          0  1600      3      6    1065
#
#       Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol
# 989               0                 0                 1
# 907               0                 0                 1
# 1318              0                 0                 1
# 818               0                 0                 1
# 661               0                 0                 1

# %%
ytrain
# Out:
# 989      9950
# 907      8950
# 1318     8500
# 818      8950
# 661      9750
#         ...
# 716      8750
# 906      9750
# 1097     7250
# 236     10950
# 1062     6750
# Name: Price, Length: 1148, dtype: int64

# %% [markdown]
# ## Model Building

# %%
model = smf.ols('Price~Age_08_04+KM+HP+Automatic+cc+Doors+Gears+Weight+Fuel_Type_CNG+Fuel_Type_Diesel+Fuel_Type_Petrol',data=tcd).fit()

# %% [markdown]
# ## 1. Resudal Plot

# %%
model.params
# Out:
# Intercept          -6895.217001
# Age_08_04           -123.840430
# KM                    -0.017416
# HP                    23.314614
# Automatic            303.253603
# cc                    -0.052021
# Doors                -29.884035
# Gears                627.081986
# Weight                20.706603
# Fuel_Type_CNG      -2858.978150
# Fuel_Type_Diesel   -2321.979227
# Fuel_Type_Petrol   -1714.259624
# dtype: float64

# %%
model.rsquared
# Out:
# 0.8637648551448405

# %%
model.fittedvalues
# Out:
# 0       16279.391959
# 1       15827.430557
# 2       16247.420682
# 3       15890.210892
# 4       15663.833741
#             ...
# 1431     8695.195996
# 1432     8143.498909
# 1433     8301.892590
# 1434     8427.474616
# 1435    10513.153028
# Length: 1435, dtype: float64

# %%
model.resid
# Out:
# 0      -2779.391959
# 1      -2077.430557
# 2      -2297.420682
# 3       -940.210892
# 4      -1913.833741
#            ...
# 1431   -1195.195996
# 1432    2701.501091
# 1433     198.107410
# 1434   -1177.474616
# 1435   -3563.153028
# Length: 1435, dtype: float64

# %%
plt.scatter(model.fittedvalues,model.resid)
plt.title('Predicted Valued Vs Residuals ')
plt.xlabel('Predicted Valued')
plt.ylabel('Residuals')
# Out:
# Text(0, 0.5, 'Residuals')

# %%
import statsmodels.api as sm

# %% [markdown]
# ##  2. QQPLOT

# %%
model.params
# Out:
# Intercept          -6895.217001
# Age_08_04           -123.840430
# KM                    -0.017416
# HP                    23.314614
# Automatic            303.253603
# cc                    -0.052021
# Doors                -29.884035
# Gears                627.081986
# Weight                20.706603
# Fuel_Type_CNG      -2858.978150
# Fuel_Type_Diesel   -2321.979227
# Fuel_Type_Petrol   -1714.259624
# dtype: float64

# %%
model.fittedvalues
# Out:
# 0       16279.391959
# 1       15827.430557
# 2       16247.420682
# 3       15890.210892
# 4       15663.833741
#             ...
# 1431     8695.195996
# 1432     8143.498909
# 1433     8301.892590
# 1434     8427.474616
# 1435    10513.153028
# Length: 1435, dtype: float64

# %%
model.resid
# Out:
# 0      -2779.391959
# 1      -2077.430557
# 2      -2297.420682
# 3       -940.210892
# 4      -1913.833741
#            ...
# 1431   -1195.195996
# 1432    2701.501091
# 1433     198.107410
# 1434   -1177.474616
# 1435   -3563.153028
# Length: 1435, dtype: float64

# %%
import statsmodels.api as sm

sm.qqplot(model.resid,line='q');

# %% [markdown]
# ## 3. Residual vs Regressor

# %%
sm.graphics.plot_regress_exog(model,'KM');

# %%
sm.graphics.plot_regress_exog(model,'HP');

# %%
sm.graphics.plot_regress_exog(model,'Automatic');

# %%
sm.graphics.plot_regress_exog(model,'cc');

# %%
sm.graphics.plot_regress_exog(model,'Gears');

# %% [markdown]
# ## Model Detection Diagnostics (checking Outliers or Influencers)
# - Two Techniques : 1. Cook's Distance & 2. Leverage value

# %%
# 1. Cook's Distance: If Cook's distance > 1, then it's an outlier
# Get influencers using cook's distance
(c,_)=model.get_influence().cooks_distance
c
# Out:
# array([4.20329555e-03, 2.12736364e-03, 2.95311457e-03, ...,
#        1.24558008e-05, 4.30330817e-04, 7.04076283e-03])

# %%
# Plot the influencers using the stem plot
fig=plt.figure(figsize=(20,7))
plt.stem(np.arange(len(tcd)),np.round(c,3))
plt.xlabel('Row Index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
# Index and value of influencer where C>0.5
np.argmax(c) , np.max(c)
# Out:
# (80, 153.5889262480368)

# %%
# 2. Leverage Value using High Influence Points : Points beyond Leverage_cutoff value are influencers
fig,ax=plt.subplots(figsize=(20,20))
fig=influence_plot(model,ax = ax)

# %%
# Leverage Cuttoff Value = 3*(k+1)/n ; k = no.of features/columns & n = no. of datapoints
k=tcd.shape[1]
n=tcd.shape[0]
leverage_cutoff = (3*(k+1))/n
leverage_cutoff
# Out:
# 0.027177700348432057

# %%
tcd[tcd.index.isin([80])]
# Out:
#     Price  Age_08_04     KM   HP  Automatic     cc  Doors  Gears  Weight  \
# 80  18950         25  20019  110          1  16000      5      5    1180
#
#     Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol
# 80              0                 0                 1

# %% [markdown]
# # Improving the Model

# %%
# Creating a copy of data so that original dataset is not affected

tcd_new=tcd.copy()
tcd_new
# Out:
#       Price  Age_08_04     KM   HP  Automatic    cc  Doors  Gears  Weight  \
# 0     13500         23  46986   90          0  2000      3      5    1165
# 1     13750         23  72937   90          0  2000      3      5    1165
# 2     13950         24  41711   90          0  2000      3      5    1165
# 3     14950         26  48000   90          0  2000      3      5    1165
# 4     13750         30  38500   90          0  2000      3      5    1170
# ...     ...        ...    ...  ...        ...   ...    ...    ...     ...
# 1431   7500         69  20544   86          0  1300      3      5    1025
# 1432  10845         72  19000   86          0  1300      3      5    1015
# 1433   8500         71  17016   86          0  1300      3      5    1015
# 1434   7250         70  16916   86          0  1300      3      5    1015
# 1435   6950         76      1  110          0  1600      5      5    1114
#
#       Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol
# 0                 0                 1                 0
# 1                 0                 1                 0
# 2                 0                 1                 0
# 3                 0                 1                 0
# 4                 0                 1                 0
# ...             ...               ...               ...
# 1431              0                 0                 1
# 1432              0                 0                 1
# 1433              0                 0                 1
# 1434              0                 0                 1
# 1435              0                 0                 1
#
# [1435 rows x 12 columns]

# %%
# Discard the data points which are influencers and reassign the row number (reset_index(drop=True))
toyo5=tcd_new.drop(tcd_new.index[[80]],axis=0).reset_index(drop=True)
toyo5
# Out:
#       Price  Age_08_04     KM   HP  Automatic    cc  Doors  Gears  Weight  \
# 0     13500         23  46986   90          0  2000      3      5    1165
# 1     13750         23  72937   90          0  2000      3      5    1165
# 2     13950         24  41711   90          0  2000      3      5    1165
# 3     14950         26  48000   90          0  2000      3      5    1165
# 4     13750         30  38500   90          0  2000      3      5    1170
# ...     ...        ...    ...  ...        ...   ...    ...    ...     ...
# 1429   7500         69  20544   86          0  1300      3      5    1025
# 1430  10845         72  19000   86          0  1300      3      5    1015
# 1431   8500         71  17016   86          0  1300      3      5    1015
# 1432   7250         70  16916   86          0  1300      3      5    1015
# 1433   6950         76      1  110          0  1600      5      5    1114
#
#       Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol
# 0                 0                 1                 0
# 1                 0                 1                 0
# 2                 0                 1                 0
# 3                 0                 1                 0
# 4                 0                 1                 0
# ...             ...               ...               ...
# 1429              0                 0                 1
# 1430              0                 0                 1
# 1431              0                 0                 1
# 1432              0                 0                 1
# 1433              0                 0                 1
#
# [1434 rows x 12 columns]

# %% [markdown]
# # Model Detection Diagnostics and Final Model

# %%
 while np.max(c)>0.5 :
    model=smf.ols('Price~Age_08_04+KM+HP+cc+Doors+Gears+Weight',data=toyo5).fit()
    (c,_)=model.get_influence().cooks_distance
    c
    np.argmax(c) , np.max(c)
    toyo5=toyo5.drop(toyo5.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
    toyo5
else:
    final_model=smf.ols('Price~Age_08_04+KM+HP+cc+Doors+Gears+Weight',data=toyo5).fit()
    final_model.rsquared , final_model.aic
    print("Thus model accuracy is improved to",final_model.rsquared)
# Out:
# Thus model accuracy is improved to 0.8876768823747953

# %%
if np.max(c)>0.5:
    model=smf.ols('Price~Age_08_04+KM+HP+cc+Doors+Gears+Weight',data=toyo5).fit()
    (c,_)=model.get_influence().cooks_distance
    c
    np.argmax(c) , np.max(c)
    toyo5=toyo5.drop(toyo5.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
    toyo5 
elif np.max(c)<0.5:
    final_model=smf.ols('Price~Age_08_04+KM+HP+cc+Doors+Gears+Weight',data=toyo5).fit()
    final_model.rsquared , final_model.aic
    print("Thus model accuracy is improved to",final_model.rsquared)
# Out:
# Thus model accuracy is improved to 0.8876768823747953

# %%
final_model.rsquared
# Out:
# 0.8876768823747953

# %%
toyo5
# Out:
#       Price  Age_08_04     KM   HP  Automatic    cc  Doors  Gears  Weight  \
# 0     13500         23  46986   90          0  2000      3      5    1165
# 1     13750         23  72937   90          0  2000      3      5    1165
# 2     13950         24  41711   90          0  2000      3      5    1165
# 3     14950         26  48000   90          0  2000      3      5    1165
# 4     13750         30  38500   90          0  2000      3      5    1170
# ...     ...        ...    ...  ...        ...   ...    ...    ...     ...
# 1426   7500         69  20544   86          0  1300      3      5    1025
# 1427  10845         72  19000   86          0  1300      3      5    1015
# 1428   8500         71  17016   86          0  1300      3      5    1015
# 1429   7250         70  16916   86          0  1300      3      5    1015
# 1430   6950         76      1  110          0  1600      5      5    1114
#
#       Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol
# 0                 0                 1                 0
# 1                 0                 1                 0
# 2                 0                 1                 0
# 3                 0                 1                 0
# 4                 0                 1                 0
# ...             ...               ...               ...
# 1426              0                 0                 1
# 1427              0                 0                 1
# 1428              0                 0                 1
# 1429              0                 0                 1
# 1430              0                 0                 1
#
# [1431 rows x 12 columns]

# %% [markdown]
# # Model Prediction

# %%
#  New data for prediction is

new_data=pd.DataFrame({'Age_08_04':12,"KM":40000,"HP":80,"cc":1300,"Doors":4,"Gears":5,"Weight":1012},index=[0])
new_data
# Out:
#    Age_08_04     KM  HP    cc  Doors  Gears  Weight
# 0         12  40000  80  1300      4      5    1012

# %%
# Manual Prediction of Price

final_model.predict(new_data)
# Out:
# 0    14320.039208
# dtype: float64

# %%
# Automatic Prediction of Price with 90.02% accurcy

pred_y=final_model.predict(toyo5)
pred_y
# Out:
# 0       16198.360543
# 1       15746.702250
# 2       16179.666315
# 3       15849.207301
# 4       15740.147564
#             ...
# 1426     9132.186959
# 1427     8492.340356
# 1428     8637.372204
# 1429     8749.614401
# 1430    11118.305918
# Length: 1431, dtype: float64

# %% [markdown]
# # Lasso and Ridge Method

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error
from sklearn.datasets import make_regression

# %%
# 1. Lasso Regression

# %%
# Creating a Lasso regression model with alpha=0.1 (regularization strength)
lasso_model = Lasso(alpha=0.1)

# Fitting the model
lasso_model.fit(xtrain, ytrain)
# Out:
# Lasso(alpha=0.1)

# %%
# Making predictions
y_pred_lasso = lasso_model.predict(xtest)

# Calculating Mean Squared Error for Lasso
lasso_mse = mean_squared_error(ytest, y_pred_lasso)

print("Lasso Regression Mean Squared Error:", lasso_mse)
# Out:
# Lasso Regression Mean Squared Error: 13710736.834395295

# %%
# 2. Ridge Regression

# %%
# Creating a Ridge regression model with alpha=1.0 (regularization strength)
ridge_model = Ridge(alpha=1.0)

# Fitting the model
ridge_model.fit(xtrain, ytrain)
# Out:
# Ridge()

# %%
# Making predictions
y_pred_ridge = ridge_model.predict(xtest)

# Calculating Mean Squared Error for Ridge
ridge_mse = mean_squared_error(ytest, y_pred_ridge)

print("Ridge Regression Mean Squared Error:", ridge_mse)
# Out:
# Ridge Regression Mean Squared Error: 12308890.439787729

# %%
# PLot

plt.figure(figsize=(10, 6))
plt.plot(ridge_model.coef_, label='Ridge Coefficients', marker='x')
plt.plot(lasso_model.coef_, label='Lasso Coefficients', marker='s')
plt.title("Comparison of Coefficients in , Ridge, and Lasso Regression")
plt.xlabel('Features')
plt.ylabel('Coefficient Value')
plt.legend()
plt.show()

# %% [markdown]
# # Interview Questions

# %% [markdown]
# 1) What is Normalization & Standardization and how is it helpful?
# - Normalization and Standardization are two techniques used in data preprocessing, especially in machine learning, to bring all features to a similar scale or range.
# When to use Normalisation :- When features have different ranges (e.g., one in thousands, another in decimals).
# When algorithms like KNN or Neural Networks are sensitive to the scale of data.
#
# When to use Standardization :- When the algorithm assumes normally distributed data (e.g., Linear Regression, Logistic Regression).
# When the scale doesn’t matter as much, but the distribution does.
#
# These techniques are helpful when -
# Improved Algorithm Performance: Algorithms like gradient descent converge faster when features are on a similar scale.
# Prevents Bias: Features with larger scales won’t dominate over smaller-scaled ones.
# Better Interpretability: Scaling ensures that distance-based metrics (used in clustering or classification) work correctly.
# Consistency: It creates consistency in how features are treated.
#
# 2) What techniques can be used to address multicollinearity in multiple linear regression?
# - Multicollinearity occurs when predictor variables in multiple linear regression are highly correlated, leading to unstable coefficients and difficulty in interpretation. To address it:
# Remove Highly Correlated Variables using a correlation matrix or Variance Inflation Factor (VIF).
# Combine Predictors (e.g., using Principal Component Analysis).
# Use Regularization Techniques like Ridge or Lasso Regression to reduce the impact of multicollinearity.
# Increase Sample Size if feasible to stabilize estimates.
# Apply domain knowledge to select the most relevant predictors.
# These techniques improve model stability and interpretability.
